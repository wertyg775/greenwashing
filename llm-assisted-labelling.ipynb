# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/eval_products_100.csv")

# %%
df.columns
# Out:
# Index(['PRODUCT_ID', 'combined_text', 'claim_strength'], dtype='object')

# %%
df.head()
# Out:
#    PRODUCT_ID                                      combined_text  \
# 0      901852  FANMATS NBA Miami Heat Nylon Face Basketball R...
# 1     2251841  Kitchen Table Runner 14"x72", Marble Texture A...
# 2     2185165  VKAIRE Soft Comfortable Organic Cotton Wiggly ...
# 3     2902869  Ambesonne Pug Duvet Cover Set of 2, Puppy on T...
# 4     2858697  Mayabi Women's Soft Cotton Silk Dhakai Jamdani...
#
#   claim_strength
# 0         strong
# 1         strong
# 2         strong
# 3           weak
# 4         medium

# %%
# TEST CELL - Run this first to test one row
import google.generativeai as genai
import pandas as pd
import json

genai.configure(api_key='AIzaSyCyj2qCl96ndqjwe8tp5nXXxcO_sfDU8dg')
model = genai.GenerativeModel('gemini-3-pro-preview')

# Test with your sample description
test_description = """Angel Mineral Foldable Bed Study Table Portable Laptop Table Lapdesk for Children Bed Work Office Gaming Home with Tablet Slot & Cup Holder Bed Breakfast Serving Table Angel mineral Material environmental protection„Äë- The desktop is made of MDF, solid wood particle board, safe and environmentally friendly."""

def clean_text(text):
    if pd.isna(text):
        return ""
    return str(text).encode('utf-8', errors='ignore').decode('utf-8')

def test_label(description, prompt_type='zero_shot'):
    description = clean_text(description)
    
    prompt = f"""Analyze whether this product contains greenwashing.

Product: {description}

Respond in JSON format:
{{"label": "yes/no/uncertain", "confidence": 0.0-1.0}}"""
    
    print("=== PROMPT ===")
    print(prompt[:500])
    print("\n=== SENDING REQUEST ===")
    
    response = model.generate_content(prompt, generation_config=genai.GenerationConfig(temperature=0.7))
    
    print("\n=== RAW RESPONSE ===")
    print(response.text)
    
    text = response.text.strip()
    if '```json' in text:
        text = text.split('```json')[1].split('```')[0].strip()
    elif '```' in text:
        text = text.split('```')[1].split('```')[0].strip()
    
    print("\n=== EXTRACTED JSON ===")
    print(text)
    
    result = json.loads(text)
    print("\n=== PARSED RESULT ===")
    print(f"Label: {result['label']}")
    print(f"Confidence: {result['confidence']}")
    
    return result['label'], result['confidence']

# Test it
label, conf = test_label(test_description)
# Out:
# === PROMPT ===
# Analyze whether this product contains greenwashing.
#
# Product: Angel Mineral Foldable Bed Study Table Portable Laptop Table Lapdesk for Children Bed Work Office Gaming Home with Tablet Slot & Cup Holder Bed Breakfast Serving Table Angel mineral Material environmental protection„Äë- The desktop is made of MDF, solid wood particle board, safe and environmentally friendly.
#
# Respond in JSON format:
# {"label": "yes/no/uncertain", "confidence": 0.0-1.0}
#
# === SENDING REQUEST ===
#
# === RAW RESPONSE ===
# ```json
# {
#   "label": "yes",
#   "confidence": 0.95
# }
# ```
#
# === EXTRACTED JSON ===
# {
#   "label": "yes",
#   "confidence": 0.95
# }
#
# === PARSED RESULT ===
# Label: yes
# Confidence: 0.95

# %%
# MAIN CELL - Run this after test succeeds
import google.generativeai as genai
import pandas as pd
import json
import time
from tenacity import retry, stop_after_attempt, wait_exponential

model = genai.GenerativeModel('gemini-3-pro-preview')

PROMPTS = {
    'zero_shot': """Analyze whether this product contains greenwashing.

Product: {description}

Respond in JSON format:
{{"label": "greenwashing/not_greenwashing/uncertain", "confidence": 0.0-1.0}}""",
    
    'one_shot': """Analyze whether products contain greenwashing.

Example:
Product: "Eco-friendly and natural ingredients"
Analysis: {{"label": "greenwashing", "confidence": 0.85}}
Reason: Vague, unsubstantiated claims

Now analyze this product:

Product: {description}

Respond in JSON format:
{{"label": "greenwashing/not_greenwashing/uncertain", "confidence": 0.0-1.0}}""",
    
    'chain_of_thought': """Analyze whether this product contains greenwashing.

Product: {description}

Evaluate across ALL dimensions:

1. SPECIFICITY & EVIDENCE
   - Are claims specific with certifications (GOTS, FSC, Fair Trade, etc.)?
   - Are there measurable metrics (percentages, quantities, comparisons)?
   - Or only vague terms (eco-friendly, sustainable, natural)?

2. TONE & LANGUAGE
   - Is language neutral and factual?
   - Or overly emotional, enthusiastic, or exaggerated?
   - Excessive exclamations, emojis, or superlatives?

3. TRANSPARENCY & SUBSTANCE
   - Is enough information provided to verify claims?
   - Are there hidden tradeoffs or misleading emphasis?
   - Does it highlight minor benefits while ignoring major impacts?

4. OVERALL CREDIBILITY
   - Do environmental benefits seem genuine and proportionate?
   - Is this substantive environmental action or just marketing?

GREENWASHING = Vague claims + emotional language + lack of evidence
NOT GREENWASHING = Specific claims + neutral tone + verifiable evidence

Respond in JSON format:
{{"label": "greenwashing/not_greenwashing/uncertain", "confidence": 0.0-1.0, "key_reason": "brief explanation"}}"""
}

def clean_text(text):
    if pd.isna(text):
        return ""
    return str(text).encode('utf-8', errors='ignore').decode('utf-8')

# %%
import os

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def label_greenwashing(description, prompt_type):
    description = clean_text(description)
    prompt = PROMPTS[prompt_type].format(description=description)
    
    response = model.generate_content(prompt, generation_config=genai.GenerationConfig(temperature=0.7))
    text = response.text.strip()
    
    if '```json' in text:
        text = text.split('```json')[1].split('```')[0].strip()
    elif '```' in text:
        text = text.split('```')[1].split('```')[0].strip()
    
    result = json.loads(text)
    return result['label'], result['confidence']

# Check which files already exist
all_prompt_types = ['zero_shot', 'one_shot', 'chain_of_thought']
remaining_prompts = [pt for pt in all_prompt_types if not os.path.exists(f'greenwashing_{pt}.csv')]

print(f"Already completed: {[pt for pt in all_prompt_types if os.path.exists(f'greenwashing_{pt}.csv')]}")
print(f"Remaining to process: {remaining_prompts}\n")

for prompt_type in remaining_prompts:
    print(f"\n=== Processing {prompt_type} ===")
    
    df_result = df.copy()
    results = []
    
    for idx, desc in enumerate(df_result['combined_text']):
        try:
            label, conf = label_greenwashing(desc, prompt_type)
            results.append((label, conf))
            print(f"Processed {idx+1}/100 - Label: {label}")
            time.sleep(2)
        except Exception as e:
            print(f"Error at {idx+1}: {str(e)}")
            results.append(('error', 0.0))
    
    df_result['greenwashing'] = [r[0] for r in results]
    df_result['confidence'] = [r[1] for r in results]
    
    df_result.to_csv(f'data/benchmark/greenwashing_{prompt_type}.csv', index=False)
    print(f"Saved to greenwashing_{prompt_type}.csv")

if not remaining_prompts:
    print("All prompt types already completed!")
# Out:
# Already completed: []
# Remaining to process: ['zero_shot', 'one_shot', 'chain_of_thought']
#
#
# === Processing zero_shot ===
# Processed 1/100 - Label: not_greenwashing
# Processed 2/100 - Label: greenwashing
# Processed 3/100 - Label: not_greenwashing
# Processed 4/100 - Label: greenwashing
# Processed 5/100 - Label: greenwashing
# Processed 6/100 - Label: not_greenwashing
# Processed 7/100 - Label: greenwashing
# Processed 8/100 - Label: greenwashing
# Processed 9/100 - Label: not_greenwashing
# Processed 10/100 - Label: greenwashing
# Processed 11/100 - Label: greenwashing
# Processed 12/100 - Label: greenwashing
# Processed 13/100 - Label: not_greenwashing
# Processed 14/100 - Label: greenwashing
# Processed 15/100 - Label: greenwashing
# Processed 16/100 - Label: greenwashing
# Processed 17/100 - Label: not_greenwashing
# Processed 18/100 - Label: greenwashing
# Processed 19/100 - Label: greenwashing
# Processed 20/100 - Label: not_greenwashing
# Processed 21/100 - Label: not_greenwashing
# Processed 22/100 - Label: greenwashing
# Processed 23/100 - Label: greenwashing
# Processed 24/100 - Label: greenwashing
# Processed 25/100 - Label: greenwashing
# Processed 26/100 - Label: not_greenwashing
# Processed 27/100 - Label: not_greenwashing
# Processed 28/100 - Label: greenwashing
# Processed 29/100 - Label: greenwashing
# Processed 30/100 - Label: not_greenwashing
# Processed 31/100 - Label: not_greenwashing
# Processed 32/100 - Label: greenwashing
# Processed 33/100 - Label: greenwashing
# Processed 34/100 - Label: not_greenwashing
# Processed 35/100 - Label: greenwashing
# Processed 36/100 - Label: not_greenwashing
# Processed 37/100 - Label: greenwashing
# Processed 38/100 - Label: not_greenwashing
# Processed 39/100 - Label: greenwashing
# Processed 40/100 - Label: greenwashing
# Processed 41/100 - Label: not_greenwashing
# Processed 42/100 - Label: not_greenwashing
# Processed 43/100 - Label: greenwashing
# Processed 44/100 - Label: greenwashing
# Processed 45/100 - Label: greenwashing
# Processed 46/100 - Label: greenwashing
# Processed 47/100 - Label: greenwashing
# Processed 48/100 - Label: greenwashing
# Processed 49/100 - Label: not_greenwashing
# Processed 50/100 - Label: greenwashing
# Processed 51/100 - Label: greenwashing
# Processed 52/100 - Label: greenwashing
# Processed 53/100 - Label: greenwashing
# Processed 54/100 - Label: greenwashing
# Processed 55/100 - Label: not_greenwashing
# Processed 56/100 - Label: greenwashing
# Processed 57/100 - Label: not_greenwashing
# Processed 58/100 - Label: not_greenwashing
# Processed 59/100 - Label: not_greenwashing
# Processed 60/100 - Label: greenwashing
# Processed 61/100 - Label: greenwashing
# Processed 62/100 - Label: not_greenwashing
# Processed 63/100 - Label: greenwashing
# Processed 64/100 - Label: greenwashing
# Processed 65/100 - Label: not_greenwashing
# Processed 66/100 - Label: not_greenwashing
# Processed 67/100 - Label: greenwashing
# Processed 68/100 - Label: greenwashing
# Processed 69/100 - Label: greenwashing
# Processed 70/100 - Label: not_greenwashing
# Processed 71/100 - Label: greenwashing
# Processed 72/100 - Label: greenwashing
# Processed 73/100 - Label: greenwashing
# Processed 74/100 - Label: greenwashing
# Processed 75/100 - Label: greenwashing
# Processed 76/100 - Label: not_greenwashing
# Processed 77/100 - Label: not_greenwashing
# Processed 78/100 - Label: greenwashing
# Processed 79/100 - Label: greenwashing
# Processed 80/100 - Label: greenwashing
# Processed 81/100 - Label: not_greenwashing
# Processed 82/100 - Label: greenwashing
# Processed 83/100 - Label: not_greenwashing
# Processed 84/100 - Label: not_greenwashing
# Processed 85/100 - Label: not_greenwashing
# Processed 86/100 - Label: greenwashing
# Processed 87/100 - Label: greenwashing
# Processed 88/100 - Label: greenwashing
# Processed 89/100 - Label: greenwashing
# Processed 90/100 - Label: not_greenwashing
# Processed 91/100 - Label: greenwashing
# Processed 92/100 - Label: greenwashing
# Processed 93/100 - Label: greenwashing
# Processed 94/100 - Label: not_greenwashing
# Processed 95/100 - Label: greenwashing
# Processed 96/100 - Label: greenwashing
# Processed 97/100 - Label: greenwashing
# Processed 98/100 - Label: not_greenwashing
# Processed 99/100 - Label: greenwashing
# Processed 100/100 - Label: not_greenwashing
# Saved to greenwashing_zero_shot.csv
#
# === Processing one_shot ===
# Processed 1/100 - Label: not_greenwashing
# Processed 2/100 - Label: greenwashing
# Processed 3/100 - Label: not_greenwashing
# Processed 4/100 - Label: greenwashing
# Processed 5/100 - Label: greenwashing
# Processed 6/100 - Label: not_greenwashing
# Processed 7/100 - Label: greenwashing
# Processed 8/100 - Label: greenwashing
# Processed 9/100 - Label: not_greenwashing
# Processed 10/100 - Label: greenwashing
# Processed 11/100 - Label: greenwashing
# Processed 12/100 - Label: greenwashing
# Processed 13/100 - Label: not_greenwashing
# Processed 14/100 - Label: greenwashing
# Processed 15/100 - Label: greenwashing
# Processed 16/100 - Label: greenwashing
# Processed 17/100 - Label: not_greenwashing
# Processed 18/100 - Label: not_greenwashing
# Processed 19/100 - Label: greenwashing
# Processed 20/100 - Label: not_greenwashing
# Processed 21/100 - Label: not_greenwashing
# Processed 22/100 - Label: greenwashing
# Processed 23/100 - Label: greenwashing
# Processed 24/100 - Label: greenwashing
# Processed 25/100 - Label: greenwashing
# Processed 26/100 - Label: not_greenwashing
# Processed 27/100 - Label: not_greenwashing
# Processed 28/100 - Label: greenwashing
# Processed 29/100 - Label: not_greenwashing
# Processed 30/100 - Label: not_greenwashing
# Processed 31/100 - Label: not_greenwashing
# Processed 32/100 - Label: greenwashing
# Processed 33/100 - Label: greenwashing
# Processed 34/100 - Label: not_greenwashing
# Processed 35/100 - Label: not_greenwashing
# Processed 36/100 - Label: not_greenwashing
# Processed 37/100 - Label: greenwashing
# Processed 38/100 - Label: not_greenwashing
# Processed 39/100 - Label: greenwashing
# Processed 40/100 - Label: greenwashing
# Processed 41/100 - Label: not_greenwashing
# Processed 42/100 - Label: not_greenwashing
# Processed 43/100 - Label: greenwashing
# Processed 44/100 - Label: greenwashing
# Processed 45/100 - Label: greenwashing
# Processed 46/100 - Label: greenwashing
# Processed 47/100 - Label: greenwashing
# Processed 48/100 - Label: greenwashing
# Processed 49/100 - Label: not_greenwashing
# Processed 50/100 - Label: greenwashing
# Processed 51/100 - Label: greenwashing
# Processed 52/100 - Label: greenwashing
# Processed 53/100 - Label: greenwashing
# Processed 54/100 - Label: greenwashing
# Processed 55/100 - Label: not_greenwashing
# Processed 56/100 - Label: greenwashing
# Processed 57/100 - Label: greenwashing
# Processed 58/100 - Label: not_greenwashing
# Processed 59/100 - Label: not_greenwashing
# Processed 60/100 - Label: greenwashing
# Processed 61/100 - Label: not_greenwashing
# Processed 62/100 - Label: not_greenwashing
# Processed 63/100 - Label: greenwashing
# Processed 64/100 - Label: greenwashing
# Processed 65/100 - Label: not_greenwashing
# Processed 66/100 - Label: not_greenwashing
# Processed 67/100 - Label: greenwashing
# Processed 68/100 - Label: greenwashing
# Processed 69/100 - Label: greenwashing
# Processed 70/100 - Label: not_greenwashing
# Processed 71/100 - Label: greenwashing
# Processed 72/100 - Label: greenwashing
# Processed 73/100 - Label: greenwashing
# Processed 74/100 - Label: greenwashing
# Processed 75/100 - Label: greenwashing
# Processed 76/100 - Label: not_greenwashing
# Processed 77/100 - Label: not_greenwashing
# Processed 78/100 - Label: greenwashing
# Processed 79/100 - Label: greenwashing
# Processed 80/100 - Label: greenwashing
# Processed 81/100 - Label: not_greenwashing
# Processed 82/100 - Label: greenwashing
# Processed 83/100 - Label: not_greenwashing
# Processed 84/100 - Label: not_greenwashing
# Processed 85/100 - Label: not_greenwashing
# Processed 86/100 - Label: greenwashing
# Processed 87/100 - Label: greenwashing
# Processed 88/100 - Label: greenwashing
# Processed 89/100 - Label: greenwashing
# Processed 90/100 - Label: not_greenwashing
# Processed 91/100 - Label: greenwashing
# Processed 92/100 - Label: greenwashing
# Processed 93/100 - Label: greenwashing
# Processed 94/100 - Label: not_greenwashing
# Processed 95/100 - Label: greenwashing
# Processed 96/100 - Label: greenwashing
# Processed 97/100 - Label: not_greenwashing
# Processed 98/100 - Label: not_greenwashing
# Processed 99/100 - Label: greenwashing
# Processed 100/100 - Label: not_greenwashing
# Saved to greenwashing_one_shot.csv
#
# === Processing chain_of_thought ===
# Processed 1/100 - Label: not_greenwashing
# Processed 2/100 - Label: greenwashing
# Processed 3/100 - Label: not_greenwashing
# Processed 4/100 - Label: greenwashing
# Processed 5/100 - Label: greenwashing
# Processed 6/100 - Label: greenwashing
# Processed 7/100 - Label: greenwashing
# Processed 8/100 - Label: greenwashing
# Processed 9/100 - Label: not_greenwashing
# Processed 10/100 - Label: greenwashing
# Processed 11/100 - Label: greenwashing
# Processed 12/100 - Label: greenwashing
# Processed 13/100 - Label: not_greenwashing
# Processed 14/100 - Label: greenwashing
# Processed 15/100 - Label: greenwashing
# Processed 16/100 - Label: greenwashing
# Processed 17/100 - Label: not_greenwashing
# Processed 18/100 - Label: greenwashing
# Processed 19/100 - Label: greenwashing
# Processed 20/100 - Label: not_greenwashing
# Processed 21/100 - Label: greenwashing
# Processed 22/100 - Label: greenwashing
# Processed 23/100 - Label: greenwashing
# Processed 24/100 - Label: greenwashing
# Processed 25/100 - Label: greenwashing
# Processed 26/100 - Label: not_greenwashing
# Processed 27/100 - Label: not_greenwashing
# Processed 28/100 - Label: greenwashing
# Processed 29/100 - Label: greenwashing
# Processed 30/100 - Label: not_greenwashing
# Processed 31/100 - Label: greenwashing
# Processed 32/100 - Label: greenwashing
# Processed 33/100 - Label: greenwashing
# Processed 34/100 - Label: greenwashing
# Processed 35/100 - Label: greenwashing
# Processed 36/100 - Label: not_greenwashing
# Processed 37/100 - Label: greenwashing
# Processed 38/100 - Label: not_greenwashing
# Processed 39/100 - Label: greenwashing
# Processed 40/100 - Label: greenwashing
# Processed 41/100 - Label: not_greenwashing
# Processed 42/100 - Label: not_greenwashing
# Processed 43/100 - Label: greenwashing
# Processed 44/100 - Label: greenwashing
# Processed 45/100 - Label: greenwashing
# Processed 46/100 - Label: greenwashing
# Processed 47/100 - Label: greenwashing
# Processed 48/100 - Label: greenwashing
# Processed 49/100 - Label: uncertain
# Processed 50/100 - Label: greenwashing
# Error at 51: RetryError[<Future at 0x111af3ed0 state=finished raised ResourceExhausted>]
# Error at 52: RetryError[<Future at 0x111af02d0 state=finished raised ResourceExhausted>]
# Error at 53: RetryError[<Future at 0x111acda50 state=finished raised ResourceExhausted>]
# Error at 54: RetryError[<Future at 0x111acee50 state=finished raised ResourceExhausted>]
# Error at 55: RetryError[<Future at 0x111acff50 state=finished raised ResourceExhausted>]
# Error at 56: RetryError[<Future at 0x111ace5d0 state=finished raised ResourceExhausted>]
# Error at 57: RetryError[<Future at 0x111af0650 state=finished raised ResourceExhausted>]
# Error at 58: RetryError[<Future at 0x111af2ad0 state=finished raised ResourceExhausted>]
# Error at 59: RetryError[<Future at 0x111acc5d0 state=finished raised ResourceExhausted>]
# Error at 60: RetryError[<Future at 0x111accad0 state=finished raised ResourceExhausted>]
# Error at 61: RetryError[<Future at 0x111acd2d0 state=finished raised ResourceExhausted>]
# Error at 62: RetryError[<Future at 0x111af0c50 state=finished raised ResourceExhausted>]
# Error at 63: RetryError[<Future at 0x111af2d50 state=finished raised ResourceExhausted>]
# Error at 64: RetryError[<Future at 0x111ace3d0 state=finished raised ResourceExhausted>]
# Error at 65: RetryError[<Future at 0x111ace250 state=finished raised ResourceExhausted>]
# Error at 66: RetryError[<Future at 0x111acfbd0 state=finished raised ResourceExhausted>]
# Error at 67: RetryError[<Future at 0x111af2ed0 state=finished raised ResourceExhausted>]
# Error at 68: RetryError[<Future at 0x111af29d0 state=finished raised ResourceExhausted>]
# Error at 69: RetryError[<Future at 0x111acdb50 state=finished raised ResourceExhausted>]
# Error at 70: RetryError[<Future at 0x111acd650 state=finished raised ResourceExhausted>]
# Error at 71: RetryError[<Future at 0x111acd0d0 state=finished raised ResourceExhausted>]
# Error at 72: RetryError[<Future at 0x111af00d0 state=finished raised ResourceExhausted>]
# Error at 73: RetryError[<Future at 0x111af3050 state=finished raised ResourceExhausted>]
# Error at 74: RetryError[<Future at 0x111af3150 state=finished raised ResourceExhausted>]
# Error at 75: RetryError[<Future at 0x111af3c50 state=finished raised ResourceExhausted>]
# Error at 76: RetryError[<Future at 0x111aced50 state=finished raised ResourceExhausted>]
# Error at 77: RetryError[<Future at 0x111acddd0 state=finished raised ResourceExhausted>]
# Error at 78: RetryError[<Future at 0x111a652d0 state=finished raised ResourceExhausted>]
# Error at 79: RetryError[<Future at 0x111acc050 state=finished raised ResourceExhausted>]
# Error at 80: RetryError[<Future at 0x111acc150 state=finished raised ResourceExhausted>]
# Error at 81: RetryError[<Future at 0x111af35d0 state=finished raised ResourceExhausted>]
# Error at 82: RetryError[<Future at 0x111af1050 state=finished raised ResourceExhausted>]
# Error at 83: RetryError[<Future at 0x111b2cad0 state=finished raised ResourceExhausted>]
# Error at 84: RetryError[<Future at 0x111af2650 state=finished raised ResourceExhausted>]
# Error at 85: RetryError[<Future at 0x111af1950 state=finished raised ResourceExhausted>]
# Error at 86: RetryError[<Future at 0x111acd950 state=finished raised ResourceExhausted>]
# Error at 87: RetryError[<Future at 0x111ace950 state=finished raised ResourceExhausted>]
# Error at 88: RetryError[<Future at 0x111b2ca50 state=finished raised ResourceExhausted>]
# Error at 89: RetryError[<Future at 0x111acc250 state=finished raised ResourceExhausted>]
# Error at 90: RetryError[<Future at 0x111acd950 state=finished raised ResourceExhausted>]
# Error at 91: RetryError[<Future at 0x111af00d0 state=finished raised ResourceExhausted>]
# Error at 92: RetryError[<Future at 0x111af3cd0 state=finished raised ResourceExhausted>]
# Error at 93: RetryError[<Future at 0x111b2d450 state=finished raised ResourceExhausted>]
# Error at 94: RetryError[<Future at 0x111a65e50 state=finished raised ResourceExhausted>]
# Error at 95: RetryError[<Future at 0x111af0150 state=finished raised ResourceExhausted>]
# Error at 96: RetryError[<Future at 0x111ace150 state=finished raised ResourceExhausted>]
# Error at 97: RetryError[<Future at 0x111ace050 state=finished raised ResourceExhausted>]
# Error at 98: RetryError[<Future at 0x111b2d3d0 state=finished raised ResourceExhausted>]
# Error at 99: RetryError[<Future at 0x111acc4d0 state=finished raised ResourceExhausted>]
# Error at 100: RetryError[<Future at 0x111aced50 state=finished raised ResourceExhausted>]
# Saved to greenwashing_chain_of_thought.csv

# %% [markdown]
# ## Retraining of error rows

# %%
# RETRY CELL - Retrain only error cases from chain_of_thought
import google.generativeai as genai
import pandas as pd
import json
import time
from tenacity import retry, stop_after_attempt, wait_exponential

# Initialize model
model = genai.GenerativeModel('gemini-3-pro-preview')

# Chain of thought prompt
COT_PROMPT = """Analyze whether this product contains greenwashing.
Product: {description}
Evaluate across ALL dimensions:
1. SPECIFICITY & EVIDENCE
   - Are claims specific with certifications (GOTS, FSC, Fair Trade, etc.)?
   - Are there measurable metrics (percentages, quantities, comparisons)?
   - Or only vague terms (eco-friendly, sustainable, natural)?
2. TONE & LANGUAGE
   - Is language neutral and factual?
   - Or overly emotional, enthusiastic, or exaggerated?
   - Excessive exclamations, emojis, or superlatives?
3. TRANSPARENCY & SUBSTANCE
   - Is enough information provided to verify claims?
   - Are there hidden tradeoffs or misleading emphasis?
   - Does it highlight minor benefits while ignoring major impacts?
4. OVERALL CREDIBILITY
   - Do environmental benefits seem genuine and proportionate?
   - Is this substantive environmental action or just marketing?
GREENWASHING = Vague claims + emotional language + lack of evidence
NOT GREENWASHING = Specific claims + neutral tone + verifiable evidence
Respond in JSON format:
{{"label": "greenwashing/not_greenwashing/uncertain", "confidence": 0.0-1.0, "key_reason": "brief explanation"}}"""

def clean_text(text):
    if pd.isna(text):
        return ""
    return str(text).encode('utf-8', errors='ignore').decode('utf-8')

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def label_greenwashing(description):
    description = clean_text(description)
    prompt = COT_PROMPT.format(description=description)
    
    response = model.generate_content(
        prompt, 
        generation_config=genai.GenerationConfig(temperature=0.7)
    )
    text = response.text.strip()
    
    # Clean JSON response
    if '```json' in text:
        text = text.split('```json')[1].split('```')[0].strip()
    elif '```' in text:
        text = text.split('```')[1].split('```')[0].strip()
    
    result = json.loads(text)
    return result['label'], result['confidence']

# %%
# Load the chain_of_thought results
print("Loading chain_of_thought results...")
df_cot = pd.read_csv('data/benchmark/greenwashing_chain_of_thought.csv')
# Out:
# Loading chain_of_thought results...

# %%
# Identify indices where the previous run failed
error_indices = df_cot[df_cot['greenwashing'] == 'error'].index.tolist()

if len(error_indices) == 0:
    print("No errors found! All cases already labeled.")
else:
    # Retry each error case
    successful_retries = 0
    failed_retries = []
    
    for idx in error_indices:
        try:
            desc = df_cot.loc[idx, 'combined_text']
            print(f"Retrying index {idx} ({successful_retries + 1}/{len(error_indices)})...")
            
            label, conf = label_greenwashing(desc)
            
            # Update the dataframe
            df_cot.loc[idx, 'greenwashing'] = label
            df_cot.loc[idx, 'confidence'] = conf
            
            print(f"  ✓ Success - Label: {label}, Confidence: {conf:.2f}")
            successful_retries += 1
            
            # Sleep to avoid rate limiting
            time.sleep(3)
            
        except Exception as e:
            print(f"  ✗ Failed - Error: {str(e)}")
            failed_retries.append(idx)
    
    # Save updated results
    df_cot.to_csv('data/benchmark/greenwashing_chain_of_thought.csv', index=False)
    
    print(f"\n=== RETRY SUMMARY ===")
    print(f"Total errors found: {len(error_indices)}")
    print(f"Successfully retried: {successful_retries}")
    print(f"Still failed: {len(failed_retries)}")
    
    if failed_retries:
        print(f"Failed indices: {failed_retries}")
    
    # Show remaining errors
    remaining_errors = len(df_cot[df_cot['greenwashing'] == 'error'])
    print(f"\nRemaining errors in dataset: {remaining_errors}")
    
    if remaining_errors == 0:
        print("✓ All cases successfully labeled!")
# Out:
# Retrying index 50 (1/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 51 (2/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 52 (3/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 53 (4/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 54 (5/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.95
# Retrying index 55 (6/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 56 (7/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.85
# Retrying index 57 (8/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.95
# Retrying index 58 (9/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.85
# Retrying index 59 (10/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 60 (11/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 61 (12/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.85
# Retrying index 62 (13/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 63 (14/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 64 (15/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 65 (16/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.95
# Retrying index 66 (17/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 67 (18/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 68 (19/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 69 (20/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 70 (21/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 71 (22/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 72 (23/50)...
#   ✓ Success - Label: greenwashing, Confidence: 1.00
# Retrying index 73 (24/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.85
# Retrying index 74 (25/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 75 (26/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.85
# Retrying index 76 (27/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.95
# Retrying index 77 (28/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 78 (29/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 79 (30/50)...
#   ✓ Success - Label: greenwashing, Confidence: 1.00
# Retrying index 80 (31/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.85
# Retrying index 81 (32/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 82 (33/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 83 (34/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.95
# Retrying index 84 (35/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 85 (36/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 86 (37/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 87 (38/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.85
# Retrying index 88 (39/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 89 (40/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 90 (41/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 91 (42/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 92 (43/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 93 (44/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 1.00
# Retrying index 94 (45/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 95 (46/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.95
# Retrying index 96 (47/50)...
#   ✓ Success - Label: greenwashing, Confidence: 0.90
# Retrying index 97 (48/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.90
# Retrying index 98 (49/50)...
#   ✓ Success - Label: greenwashing, Confidence: 1.00
# Retrying index 99 (50/50)...
#   ✓ Success - Label: not_greenwashing, Confidence: 0.85
#
# === RETRY SUMMARY ===
# Total errors found: 50
# Successfully retried: 50
# Still failed: 0
#
# Remaining errors in dataset: 0
# ✓ All cases successfully labeled!
